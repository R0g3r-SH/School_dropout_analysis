# %%
# Load your encoded and scaled dataset
import pandas as pd
data = pd.read_csv('./data/encoded_scaled_data.csv')

# Calculate summary statistics
summary_statistics = data.describe()
print(summary_statistics)
# Out:
#          student.id  educational.model           age  online.test  \
# count  2.431700e+04            24317.0  2.431700e+04      24317.0
# mean   7.480320e-17                0.0 -4.675200e-16          0.0
# std    1.000021e+00                0.0  1.000021e+00          0.0
# min   -2.007995e+00                0.0 -1.724144e+00          0.0
# 25%   -7.921480e-01                0.0 -2.972643e-01          0.0
# 50%    8.666954e-02                0.0 -2.972643e-01          0.0
# 75%    8.697697e-01                0.0  4.161758e-01          0.0
# max    1.762594e+00                0.0  2.824034e+01          0.0
#
#        english.evaluation  admission.rubric     retention  dropout.semester  \
# count        24317.000000      2.431700e+04  2.431700e+04      2.431700e+04
# mean             0.000000      1.683072e-16 -5.610240e-17      3.973920e-17
# std              1.000021      1.000021e+00  1.000021e+00      1.000021e+00
# min             -0.359876     -3.186417e+00 -4.480170e+00     -2.084991e-01
# 25%             -0.359876     -6.520927e-01  2.232058e-01     -2.084991e-01
# 50%             -0.359876     -1.011526e-01  2.232058e-01     -2.084991e-01
# 75%             -0.359876      7.803517e-01  2.232058e-01     -2.084991e-01
# max              3.095868      2.102608e+00  2.232058e-01      5.523636e+00
#
#        physical.education  cultural.diffusion  student.society
# count        2.431700e+04        2.431700e+04     2.431700e+04
# mean        -2.454480e-17        9.350400e-17    -7.480320e-17
# std          1.000021e+00        1.000021e+00     1.000021e+00
# min         -2.440831e+00       -1.039476e+00    -7.092888e-01
# 25%          4.096966e-01       -1.039476e+00    -7.092888e-01
# 50%          4.096966e-01        9.620234e-01    -7.092888e-01
# 75%          4.096966e-01        9.620234e-01     1.409863e+00
# max          4.096966e-01        9.620234e-01     1.409863e+00

# %% [markdown]
# Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histograms for all numerical features
data.hist(figsize=(20, 15))
plt.show()

# %%
sample_data = data.sample(frac=0.1, random_state=1)

# Calculate the correlation matrix
correlation_matrix = sample_data.corr()

# Visualize the correlation matrix
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
