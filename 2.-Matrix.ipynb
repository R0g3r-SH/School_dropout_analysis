# %%
# Load your encoded and scaled dataset
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_encoded = pd.read_csv('./data/encoded_scaled_data.csv')

# Calculate summary statistics
summary_statistics = data_encoded.describe()
print(summary_statistics)

# exposr in to another csv file oly the 1000 first rows
data_encoded.head(1000).to_csv('./data/encoded_scaled_data_head.csv', index=False)
# Out:
#        educational.model           age  online.test  english.evaluation  \
# count            24317.0  2.431700e+04      24317.0        24317.000000
# mean                 0.0 -4.675200e-16          0.0            0.000000
# std                  0.0  1.000021e+00          0.0            1.000021
# min                  0.0 -1.724144e+00          0.0           -0.359876
# 25%                  0.0 -2.972643e-01          0.0           -0.359876
# 50%                  0.0 -2.972643e-01          0.0           -0.359876
# 75%                  0.0  4.161758e-01          0.0           -0.359876
# max                  0.0  2.824034e+01          0.0            3.095868
#
#        admission.rubric     retention  dropout.semester  physical.education  \
# count      2.431700e+04  2.431700e+04      2.431700e+04        2.431700e+04
# mean       1.683072e-16 -5.610240e-17      3.973920e-17       -2.454480e-17
# std        1.000021e+00  1.000021e+00      1.000021e+00        1.000021e+00
# min       -3.186417e+00 -4.480170e+00     -2.084991e-01       -2.440831e+00
# 25%       -6.520927e-01  2.232058e-01     -2.084991e-01        4.096966e-01
# 50%       -1.011526e-01  2.232058e-01     -2.084991e-01        4.096966e-01
# 75%        7.803517e-01  2.232058e-01     -2.084991e-01        4.096966e-01
# max        2.102608e+00  2.232058e-01      5.523636e+00        4.096966e-01
#
#        cultural.diffusion  student.society
# count        2.431700e+04     2.431700e+04
# mean         9.350400e-17    -7.480320e-17
# std          1.000021e+00     1.000021e+00
# min         -1.039476e+00    -7.092888e-01
# 25%         -1.039476e+00    -7.092888e-01
# 50%          9.620234e-01    -7.092888e-01
# 75%          9.620234e-01     1.409863e+00
# max          9.620234e-01     1.409863e+00

# %%
#load the new csv file
data_encoded_head = pd.read_csv('./data/encoded_scaled_data_head.csv')

# %%
#correration matrix

correlation_matrix = data_encoded_head.corr()

print(correlation_matrix)
# Out:
#                              educational.model       age  online.test  \
# educational.model                          NaN       NaN          NaN
# age                                        NaN  1.000000          NaN
# online.test                                NaN       NaN          NaN
# english.evaluation                         NaN  0.721501          NaN
# admission.rubric                           NaN  0.119316          NaN
# ...                                        ...       ...          ...
# id.school.origin_School 993                NaN       NaN          NaN
# id.school.origin_School 994                NaN       NaN          NaN
# id.school.origin_School 995                NaN       NaN          NaN
# id.school.origin_School 996                NaN       NaN          NaN
# id.school.origin_School 999                NaN       NaN          NaN
#
#                              english.evaluation  admission.rubric  retention  \
# educational.model                           NaN               NaN        NaN
# age                                    0.721501          0.119316  -0.055614
# online.test                                 NaN               NaN        NaN
# english.evaluation                     1.000000          0.111109  -0.102075
# admission.rubric                       0.111109          1.000000  -0.044071
# ...                                         ...               ...        ...
# id.school.origin_School 993                 NaN               NaN        NaN
# id.school.origin_School 994                 NaN               NaN        NaN
# id.school.origin_School 995                 NaN               NaN        NaN
# id.school.origin_School 996                 NaN               NaN        NaN
# id.school.origin_School 999                 NaN               NaN        NaN
#
#                              dropout.semester  physical.education  \
# educational.model                         NaN                 NaN
# age                                  0.019413           -0.019368
# online.test                               NaN                 NaN
# english.evaluation                   0.083290           -0.112715
# admission.rubric                     0.035055           -0.022257
# ...                                       ...                 ...
# id.school.origin_School 993               NaN                 NaN
# id.school.origin_School 994               NaN                 NaN
# id.school.origin_School 995               NaN                 NaN
# id.school.origin_School 996               NaN                 NaN
# id.school.origin_School 999               NaN                 NaN
#
#                              cultural.diffusion  student.society  ...  \
# educational.model                           NaN              NaN  ...
# age                                   -0.125250         0.067105  ...
# online.test                                 NaN              NaN  ...
# english.evaluation                    -0.072390         0.120511  ...
# admission.rubric                      -0.234487         0.108620  ...
# ...                                         ...              ...  ...
# id.school.origin_School 993                 NaN              NaN  ...
# id.school.origin_School 994                 NaN              NaN  ...
# id.school.origin_School 995                 NaN              NaN  ...
# id.school.origin_School 996                 NaN              NaN  ...
# id.school.origin_School 999                 NaN              NaN  ...
#
#                              id.school.origin_School 986  \
# educational.model                                    NaN
# age                                                  NaN
# online.test                                          NaN
# english.evaluation                                   NaN
# admission.rubric                                     NaN
# ...                                                  ...
# id.school.origin_School 993                          NaN
# id.school.origin_School 994                          NaN
# id.school.origin_School 995                          NaN
# id.school.origin_School 996                          NaN
# id.school.origin_School 999                          NaN
#
#                              id.school.origin_School 987  \
# educational.model                                    NaN
# age                                                  NaN
# online.test                                          NaN
# english.evaluation                                   NaN
# admission.rubric                                     NaN
# ...                                                  ...
# id.school.origin_School 993                          NaN
# id.school.origin_School 994                          NaN
# id.school.origin_School 995                          NaN
# id.school.origin_School 996                          NaN
# id.school.origin_School 999                          NaN
#
#                              id.school.origin_School 989  \
# educational.model                                    NaN
# age                                                  NaN
# online.test                                          NaN
# english.evaluation                                   NaN
# admission.rubric                                     NaN
# ...                                                  ...
# id.school.origin_School 993                          NaN
# id.school.origin_School 994                          NaN
# id.school.origin_School 995                          NaN
# id.school.origin_School 996                          NaN
# id.school.origin_School 999                          NaN
#
#                              id.school.origin_School 99  \
# educational.model                                   NaN
# age                                                 NaN
# online.test                                         NaN
# english.evaluation                                  NaN
# admission.rubric                                    NaN
# ...                                                 ...
# id.school.origin_School 993                         NaN
# id.school.origin_School 994                         NaN
# id.school.origin_School 995                         NaN
# id.school.origin_School 996                         NaN
# id.school.origin_School 999                         NaN
#
#                              id.school.origin_School 991  \
# educational.model                                    NaN
# age                                                  NaN
# online.test                                          NaN
# english.evaluation                                   NaN
# admission.rubric                                     NaN
# ...                                                  ...
# id.school.origin_School 993                          NaN
# id.school.origin_School 994                          NaN
# id.school.origin_School 995                          NaN
# id.school.origin_School 996                          NaN
# id.school.origin_School 999                          NaN
#
#                              id.school.origin_School 993  \
# educational.model                                    NaN
# age                                                  NaN
# online.test                                          NaN
# english.evaluation                                   NaN
# admission.rubric                                     NaN
# ...                                                  ...
# id.school.origin_School 993                          NaN
# id.school.origin_School 994                          NaN
# id.school.origin_School 995                          NaN
# id.school.origin_School 996                          NaN
# id.school.origin_School 999                          NaN
#
#                              id.school.origin_School 994  \
# educational.model                                    NaN
# age                                                  NaN
# online.test                                          NaN
# english.evaluation                                   NaN
# admission.rubric                                     NaN
# ...                                                  ...
# id.school.origin_School 993                          NaN
# id.school.origin_School 994                          NaN
# id.school.origin_School 995                          NaN
# id.school.origin_School 996                          NaN
# id.school.origin_School 999                          NaN
#
#                              id.school.origin_School 995  \
# educational.model                                    NaN
# age                                                  NaN
# online.test                                          NaN
# english.evaluation                                   NaN
# admission.rubric                                     NaN
# ...                                                  ...
# id.school.origin_School 993                          NaN
# id.school.origin_School 994                          NaN
# id.school.origin_School 995                          NaN
# id.school.origin_School 996                          NaN
# id.school.origin_School 999                          NaN
#
#                              id.school.origin_School 996  \
# educational.model                                    NaN
# age                                                  NaN
# online.test                                          NaN
# english.evaluation                                   NaN
# admission.rubric                                     NaN
# ...                                                  ...
# id.school.origin_School 993                          NaN
# id.school.origin_School 994                          NaN
# id.school.origin_School 995                          NaN
# id.school.origin_School 996                          NaN
# id.school.origin_School 999                          NaN
#
#                              id.school.origin_School 999
# educational.model                                    NaN
# age                                                  NaN
# online.test                                          NaN
# english.evaluation                                   NaN
# admission.rubric                                     NaN
# ...                                                  ...
# id.school.origin_School 993                          NaN
# id.school.origin_School 994                          NaN
# id.school.origin_School 995                          NaN
# id.school.origin_School 996                          NaN
# id.school.origin_School 999                          NaN
#
# [8095 rows x 8095 columns]

# %%
# Select a subset of columns (first 20 columns for illustration)
subset_columns = data_encoded.columns[20:40]
data_subset = data_encoded[subset_columns]

# Calculate the correlation matrix
correlation_matrix = data_subset.corr()

import matplotlib.pyplot as plt
import seaborn as sns

# Plot the correlation matrix
plt.figure(figsize=(16, 12))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix for Selected Columns')
plt.show()
